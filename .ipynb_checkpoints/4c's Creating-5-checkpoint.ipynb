# %%
import pandas as pd

df = pd.read_csv("train.csv")

# %%
list = [x for x in range(1,10)]

# %%
list
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
df["Name"].sample(20)
# Out:
# 405                           Gale, Mr. Shadrach
# 30                      Uruchurtu, Don. Manuel E
# 92                   Chaffee, Mr. Herbert Fuller
# 449               Peuchen, Major. Arthur Godfrey
# 237             Collyer, Miss. Marjorie "Lottie"
# 214                          Kiernan, Mr. Philip
# 235                 Harknett, Miss. Alice Phoebe
# 347    Davison, Mrs. Thomas Henry (Mary E Finck)
# 629                     O'Connell, Mr. Patrick D
# 524                            Kassem, Mr. Fared
# 763    Carter, Mrs. William Ernest (Lucile Polk)
# 555                           Wright, Mr. George
# 176                Lefebre, Master. Henry Forbes
# 23                  Sloper, Mr. William Thompson
# 889                        Behr, Mr. Karl Howell
# 378                          Betros, Mr. Tannous
# 661                            Badt, Mr. Mohamed
# 365               Adahl, Mr. Mauritz Nils Martin
# 402                     Jussila, Miss. Mari Aina
# ...

# %%
def get_title(name):
    if '.' in name:
        return name.split(",")[1].split(".")[0].strip()
    else:
        return "No titles in name"

# %%
titles = set([x for x in df.Name.map(lambda x: get_title(x))])

# %%
print(titles)
# Out:
# {'Mrs', 'Miss', 'the Countess', 'Lady', 'Capt', 'Jonkheer', 'Major', 'Don', 'Mme', 'Rev', 'Mlle', 'Dr', 'Master', 'Col', 'Sir', 'Ms', 'Mr'}

# %%
def shorter_titles(x):
    title = x['Title']
    if title in ['Capt', 'Col', 'Major']:
        return 'Officer'
    elif title in ['Jonkheer', 'Don',  "the Countess", "Done", "Lady", "Sir"]:
        return "Royality"
    elif title == "Mme":
        return "Mrs"
    elif title in ["Mlle", "Ms"]:
        return "Miss"
    else:
        return title

# %%
df["Title"] = df["Name"].map(lambda x: get_title(x))

# %%
# axis=1 means go down the column not the row.so shorter_titles will apply for the Column
df["Title"] = df.apply(shorter_titles, axis=1)

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 465          466         0       3
# 17            18         1       2
# 152          153         0       3
# 505          506         0       1
# 160          161         0       3
# 799          800         0       3
# 340          341         1       2
# 25            26         1       3
# 674          675         0       2
# 268          269         1       1
# 542          543         0       3
# 397          398         0       2
# 16            17         0       3
# 553          554         1       3
# 441          442         0       3
# 771          772         0       3
# 588          589         0       3
# 647          648         1       1
# 108          109         0       3
# 165          166         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 465                    Goncalves, Mr. Manuel Estanslas    male  38.0      0
# ...

# %%
# axis=1 means go down the column not the row.so shorter_titles will apply for the Column
df["Title"] = df.apply(shorter_titles, axis=1)

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 682          683         0       3      Olsvigen, Mr. Thor Anderson    male
# 804          805         1       3          Hedman, Mr. Oskar Arvid    male
# 270          271         0       1            Cairns, Mr. Alexander    male
# 257          258         1       1             Cherry, Miss. Gladys  female
# 835          836         1       1      Compton, Miss. Sara Rebecca  female
# 158          159         0       3              Smiljanic, Mr. Mile    male
# 159          160         0       3       Sage, Master. Thomas Henry    male
# 605          606         0       3    Lindell, Mr. Edvard Bengtsson    male
# 235          236         0       3     Harknett, Miss. Alice Phoebe  female
# 780          781         1       3             Ayoub, Miss. Banoura  female
# 628          629         0       3        Bostandyeff, Mr. Guentcho    male
# ...

# %%
print(df["Title"].value_counts())
# Out:
# Mr          517
# Miss        185
# Mrs         126
# Master       40
# Dr            7
# Rev           6
# Royality      5
# Officer       5
# Name: Title, dtype: int64

# %%
df.drop("Name", axis=1, inplace=True)

# %%
df.sample(20)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch        Ticket  \
# 783          784         0       3    male   NaN      1      2    W./C. 6607
# 350          351         0       3    male  23.0      0      0          7267
# 838          839         1       3    male  32.0      0      0          1601
# 748          749         0       1    male  19.0      1      0        113773
# 453          454         1       1    male  49.0      1      0         17453
# 252          253         0       1    male  62.0      0      0        113514
# 655          656         0       2    male  24.0      2      0  S.O.C. 14879
# 793          794         0       1    male   NaN      0      0      PC 17600
# 246          247         0       3  female  25.0      0      0        347071
# 174          175         0       1    male  56.0      0      0         17764
# 193          194         1       2    male   3.0      1      1        230080
# ...
